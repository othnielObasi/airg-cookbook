# %% [markdown]
# # Fingerprinting Drift
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/othnielObasi/airg-cookbook/blob/main/20_fingerprinting_drift.ipynb)
#
# This notebook is generated from the matching cookbook recipe and is intended to run directly in Google Colab. Add GOVERNOR_API_KEY to Colab Secrets before running. Set provider keys such as OPENAI_API_KEY or ANTHROPIC_API_KEY only for recipes that call those providers.

# %%
# %pip install -q airg-client httpx

# %%
import os

try:
    from google.colab import userdata
except Exception:
    userdata = None

for key in ["GOVERNOR_API_KEY", "OPENAI_API_KEY", "ANTHROPIC_API_KEY"]:
    if not os.getenv(key) and userdata is not None:
        value = userdata.get(key)
        if value:
            os.environ[key] = value

os.environ.setdefault("GOVERNOR_URL", "https://api.airg.nov-tia.com")

missing = [key for key in ["GOVERNOR_API_KEY"] if not os.getenv(key)]
if missing:
    raise RuntimeError(
        "Missing required secret(s): " + ", ".join(missing) +
        ". Add them in Colab Secrets or your local environment."
    )

# %%
#!/usr/bin/env python3
"""
Recipe 20 â€” Agent Fingerprinting & Drift Detection
====================================================
Monitor agent behavioural baselines and detect drift.
The fingerprinting engine learns tool distributions, call velocity,
risk profiles, and sequence patterns â€” then alerts when behaviour diverges.

    pip install httpx
    export GOVERNOR_URL=https://api.airg.nov-tia.com
    export GOVERNOR_API_KEY="<your AIRG account API key>"
    python 20_fingerprinting_drift.py
"""
from __future__ import annotations
import os, httpx

url = os.getenv("GOVERNOR_URL", "https://api.airg.nov-tia.com")
headers = {"X-API-Key": os.environ["GOVERNOR_API_KEY"]}

# â”€â”€ 1. List all fingerprinted agents â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
print("ðŸ§¬ Agent Fingerprinting â€” Tracked Agents\n")

agents = httpx.get(f"{url}/fingerprint/agents", headers=headers).json()
print(f"  Tracking {agents['agent_count']} agents "
      f"({agents['total_evaluations']} total evaluations)\n")

for a in agents["agents"][:5]:
    print(f"  ðŸ¤– {a['agent_id']}")
    print(f"     Maturity   : {a['maturity']}")
    print(f"     Unique tools: {a['unique_tools']}")
    print(f"     Block rate  : {a['block_rate_pct']}%")
    print()

# â”€â”€ 2. Check drift for a specific agent â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
if agents["agents"]:
    agent_id = agents["agents"][0]["agent_id"]
    print(f"{'â”€'*60}")
    print(f"ðŸ“ˆ Drift Analysis â€” {agent_id}\n")

    drift = httpx.get(f"{url}/fingerprint/agents/{agent_id}/drift",
                      headers=headers).json()
    print(f"  Drift score: {drift['drift_score']}/100")
    print(f"  Level      : {drift['drift_level']}")
    print(f"  Alert      : {drift['alert']}\n")

    for dim in drift.get("dimensions", []):
        print(f"  [{dim['dimension']}] score={dim['score']}")
        print(f"    {dim['details']}\n")

# â”€â”€ 3. Generate some evaluations to build a fingerprint â”€â”€â”€â”€â”€â”€â”€â”€
print(f"{'â”€'*60}")
print("ðŸ”„ Building fingerprint with 5 evaluations...\n")

tools = ["read_file", "write_file", "shell_exec", "http_request", "read_file"]
for tool in tools:
    r = httpx.post(f"{url}/actions/evaluate", headers=headers, json={
        "agent_id": "drift-demo-agent",
        "tool": tool,
        "args": {"path": "/tmp/test.txt"},
    })
    d = r.json()
    print(f"  {tool}: {d['decision']} (risk={d['risk_score']})")

# Check the new agent's fingerprint
print(f"\n  Checking fingerprint for drift-demo-agent...")
drift2 = httpx.get(f"{url}/fingerprint/agents/drift-demo-agent/drift",
                   headers=headers).json()
print(f"  Drift score: {drift2['drift_score']}/100  Level: {drift2['drift_level']}")
